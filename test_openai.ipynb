# %%
a = 6

# %%
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv

load_dotenv()

llm = ChatOpenAI(
    model="gpt-5.4-nano",
    # stream_usage=True,
    # temperature=None,
    # max_tokens=None,
    # timeout=None,
    # reasoning_effort="low",
    # max_retries=2,
    # api_key="...",  # If you prefer to pass api key in directly
    # base_url="...",
    # organization="...",
    # other params...
)

# %%
output = llm.invoke("Write a poem about Hyderabad in kannada language.")

# %%
output.content
# Out:
# '**ಹೈದರಾಬಾದ್ (ಕವಿತೆ)**\n\nಚರಿತ್ರೆಯ ನಾದ ಕೇಳಿ ಗಾಳಿಯಲಿ,  \nಹೈದರಾಬಾದ್—ಕವನೆಯ ಕನಸಲಿ;  \nಮುತ್ತಿನ ಮಳೆ ಬೀಳೋ ಬಾಗಿಲಲಿ,  \nಗೋಲ್ಕೊಂಡೆಯ ಹೃದಯ ಧಡಧಡಿಸಲಿ.\n\nಬಿರ್ಲಾ ಗಗನದ ಬೆಳಕಿನ ಚಿತ್ತಾರ,  \nಮಸೀದಿಗಳ ಶಾಂತ ಸೌಮ್ಯ ಹೂಗಾರ;  \nಚಾರ್ಮಿನಾರ್ ಕಣ್ಮಣಿಯಂತೆ ನಿಂತು,  \nರಾತ್ರಿಯಲಿ ನೆನಪು ಹೊಳೆಯುತಾ ತುಂಬಿ.\n\nಹುಸೇನ್ ಸಾಗರದ ಅಲೆಗಳಲಿ,  \nಹುಕ್ಕುಮಿನ ವಾಸನೆ—ಬಿರಿಯಾನಿಯಲಿ;  \nಮಸಾಲೆಯ ಮುತ್ತು, ರುಚಿಯ ನಗೆಯು,  \nಹೃದಯದ ತಟ್ಟೆಯಲ್ಲಿ ಹಬ್ಬದ ಹಾಡು.\n\nಹಸಿರು ಉದ್ಯಾನಗಳಲಿ ಹೆಜ್ಜೆ ಇಟ್ಟು,  \nಸಂಜೆಯ ಬೆಳಕಲ್ಲಿ ಮನಸ್ಸು ತುಳುಕು;  \nಸಾಯಂಕಾಲದ ಚಾಯ್\u200c ಕಪ್\u200c ಒಂದರಲ್ಲಿ,  \nನಗು, ಮಾತು, ಕನಸು—ಎಲ್ಲವೂ ಬೆರೆತು.\n\nಹೈದರಾಬಾದ್, ನಿನ್ನ ವೈಭವ ಅಪಾರ,  \nಪಳಗಿದ ಭಾಷೆಗಳ ಸೌಹಾರ್ದದ ಸರ;  \nಎಲ್ಲರನ್ನೂ ಜೊತೆಯಲಿ ಕಟ್ಟುವ ನಗರಿ,  \nಎಂದೆಂದೂ ಬೆಳಗಲಿ ನಿನ್ನ ಅದ್ಭುತ ಬೆಳಕು.'

# %%
output2 = llm.invoke(f"convert this into hindi language: {output.content}")

# %%
output2.content
# Out:
# '**हैदराबाद (कविता)**\n\nइतिहास की धुन सुनकर, हवा में—  \nहैदराबाद, कविता के सपनों में;  \nमोती की बारिश बरसते दरवाज़े पर,  \nगोलकुंडा का दिल धक-धक करे।\n\nबिरला आसमान की रोशनी का चित्र,  \nमस्जिदों की शांत, सौम्य फूलों-सी खुशबू;  \nचारमीनार कण-कण की तरह खड़ा रहे,  \nरात में यादें चमकती रहें—भरपूर।\n\nहुसैन सागर की लहरों में,  \nहुक्के की महक—बिरयानी में;  \nमसाले का मोती, स्वाद की मुस्कान,  \nदिल की थाली में उत्सव का गीत।\n\nहरे-भरे उद्यानों में कदम रखकर,  \nशाम की रोशनी में मन डोल उठे;  \nशाम के चाय के कप में,  \nहँसी, बातें, सपने—सब मिल जाएँ।\n\nहैदराबाद, तेरा वैभव अपार,  \nपलता भाषाओं की दोस्ती का संसार;  \nसबको साथ लेकर चलता शहर,  \nसदा-सदा चमकती रहे तेरी अद्भुत रोशनी।'

# %%
output3 = llm.invoke(f"convert this into Tamil language: {output.content}")
output3.content
# Out:
# '**ஹைதராபாத் (கவிதை)**\n\nவரலாற்றின் நாதம் கேட்டுக் காற்றிலே,  \nஹைதராபாத்—கவிதையின் கனவிலே;  \nமுத்து மழை பெய்யும் வாசலிலே,  \nகோல்கொண்டாவின் இதயம் ததததிக்க.\n\nபிர்லா வானத்தின் வெளிச்சச் சித்திரம்,  \nமசூதிகளின் அமைதியான மென்மையான பூக்கள்;  \nசார்மினார் கண்மணிபோல நின்று,  \nஇரவில் நினைவு ஒளிர்ந்து, நிறைந்து.\n\nஹுஸைன் சாகரின் அலைகளிலே,  \nஹுக்குமின் வாசனை—பிரியாணியிலே;  \nமசாலையின் முத்து, சுவையின் நகை,  \nஇதயத் தட்டில் திருவிழா பாடல்.\n\nபசுமை பூங்காக்களில் கால் வைத்து,  \nமாலையின் ஒளியில் மனம் தவழ்ந்து;  \nமாலைக்குப் தேநீர் கப்பில் ஒன்றிலே,  \nசிரிப்பு, பேச்சு, கனவு—எல்லாமும் கலந்து.\n\nஹைதராபாத், உன் சிறப்பு அளவில்லா,  \nபழகிய மொழிகளின் நட்புச் சங்கிலி;  \nஎல்லாரையும் ஒன்றாக சேர்த்திடும் நகரம்,  \nஎன்றென்றும் நீ ஒளிரட்டும்—உன் அற்புத ஒளி.'
